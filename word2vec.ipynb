# %%
import requests
import pandas as pd
import time

# %%
API_KEY="AIzaSyDWqZqIEJimSaY2P7aKt1f85NrDL-STR-s"

# %%
queries = [
    "fiction",
    "non fiction",
    "science",
    "history",
    "technology",
    "programming",
    "business",
    "romance",
    "mystery",
    "fantasy",
    "psychology",
    "medical",
    "self help",
    "biography",
    "philosophy",
    "economics",
    "politics",
    "sociology",
    "geography",
    "art and design",
    "english literature",
    "religion",
    "motivational books",

    "computer science books",
    "data structures and algorithms",
    "python programming",
    "java programming",
    "machine learning books",
    "artificial intelligence books",
    "web development books",

    "engineering mathematics",
    "electrical engineering books",
    "mechanical engineering books",
    "civil engineering books",
    "electronics engineering books",

    "neet biology",
    "neet physics",
    "neet chemistry",
    "medical textbooks",
    "human anatomy books",
    "pharmacology basics",

    "jee mains physics",
    "jee advanced physics",
    "jee chemistry problems",
    "jee mathematics",

    "upsc civil services",
    "upsc gs paper 1",
    "upsc history books",
    "upsc polity books",
    "upsc geography books",
    "indian economy upsc",
    "current affairs books",

    "ssc cgl books",
    "ssc reasoning",
    "ssc maths books",
    "ssc general awareness",

    "ca foundation accounting",
    "ca inter taxation",
    "ca study material",
    "commerce books",
    "financial accounting books",

    "aptitude reasoning books",
    "quantitative aptitude",
    "logical reasoning",
    "general knowledge india",

    "school textbooks",
    "cbse books",
    "ncert books",
    "high school mathematics",
    "high school science"
]

# %%
books = []

for q in queries:

    for start in range(0, 250, 40):

        url = f"https://www.googleapis.com/books/v1/volumes?q={q}&maxResults=40&startIndex={start}&key={API_KEY}"

        response = requests.get(url)

        if response.status_code == 200:

            data = response.json()

            if "items" in data:

                for item in data["items"]:

                    info = item.get("volumeInfo", {})

                    books.append({
                        "title": info.get("title", ""),
                        "description": info.get("description", ""),
                        "authors": info.get("authors", []),
                        "categories": info.get("categories", [])
                    })
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[5], line 9
#       5 for start in range(0, 250, 40):
#       7     url = f"https://www.googleapis.com/books/v1/volumes?q={q}&maxResults=40&startIndex={start}&key={API_KEY}"
# ----> 9     response = requests.get(url)
#      11     if response.status_code == 200:
#      13         data = response.json()
#
# File ~\AppData\Roaming\Python\Python313\site-packages\requests\api.py:73, in get(url, params, **kwargs)
#      62 def get(url, params=None, **kwargs):
#      63     r"""Sends a GET request.
#      64
#      65     :param url: URL for the new :class:`Request` object.
#    (...)     70     :rtype: requests.Response
#      71     """
# ---> 73     return request("get", url, params=params, **kwargs)
#
# File ~\AppData\Roaming\Python\Python313\site-packages\requests\api.py:59, in request(method, url, **kwargs)
#      55 # By using the 'with' statement we are sure the session is closed, thus we
#      56 # avoid leaving sockets open which can trigger a ResourceWarning in some
#      57 # cases, and look like a memory leak in others.
#      58 with sessions.Session() as session:
# ---> 59     return session.request(method=method, url=url, **kwargs)
#
# File ~\AppData\Roaming\Python\Python313\site-packages\requests\sessions.py:589, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     584 send_kwargs = {
#     585     "timeout": timeout,
#     586     "allow_redirects": allow_redirects,
#     587 }
#     588 send_kwargs.update(settings)
# --> 589 resp = self.send(prep, **send_kwargs)
#     591 return resp
#
# File ~\AppData\Roaming\Python\Python313\site-packages\requests\sessions.py:703, in Session.send(self, request, **kwargs)
#     700 start = preferred_clock()
#     702 # Send the request
# --> 703 r = adapter.send(request, **kwargs)
#     705 # Total elapsed time of the request (approximately)
#     706 elapsed = preferred_clock() - start
#
# File ~\AppData\Roaming\Python\Python313\site-packages\requests\adapters.py:644, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     641     timeout = TimeoutSauce(connect=timeout, read=timeout)
#     643 try:
# --> 644     resp = conn.urlopen(
#     645         method=request.method,
#     646         url=url,
#     647         body=request.body,
#     648         headers=request.headers,
#     649         redirect=False,
#     650         assert_same_host=False,
#     651         preload_content=False,
#     652         decode_content=False,
#     653         retries=self.max_retries,
#     654         timeout=timeout,
#     655         chunked=chunked,
#     656     )
#     658 except (ProtocolError, OSError) as err:
#     659     raise ConnectionError(err, request=request)
#
# File ~\AppData\Roaming\Python\Python313\site-packages\urllib3\connectionpool.py:787, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     784 response_conn = conn if not release_conn else None
#     786 # Make the request on the HTTPConnection object
# --> 787 response = self._make_request(
#     788     conn,
#     789     method,
#     790     url,
#     791     timeout=timeout_obj,
#     792     body=body,
#     793     headers=headers,
#     794     chunked=chunked,
#     795     retries=retries,
#     796     response_conn=response_conn,
#     797     preload_content=preload_content,
#     798     decode_content=decode_content,
#     799     **response_kw,
#     800 )
#     802 # Everything went great!
#     803 clean_exit = True
#
# File ~\AppData\Roaming\Python\Python313\site-packages\urllib3\connectionpool.py:534, in HTTPConnectionPool._make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     532 # Receive the response from the server
#     533 try:
# --> 534     response = conn.getresponse()
#     535 except (BaseSSLError, OSError) as e:
#     536     self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#
# File ~\AppData\Roaming\Python\Python313\site-packages\urllib3\connection.py:571, in HTTPConnection.getresponse(self)
#     568 _shutdown = getattr(self.sock, "shutdown", None)
#     570 # Get the response from http.client.HTTPConnection
# --> 571 httplib_response = super().getresponse()
#     573 try:
#     574     assert_header_parsing(httplib_response.msg)
#
# File ~\anaconda3\Lib\http\client.py:1430, in HTTPConnection.getresponse(self)
#    1428 try:
#    1429     try:
# -> 1430         response.begin()
#    1431     except ConnectionError:
#    1432         self.close()
#
# File ~\anaconda3\Lib\http\client.py:331, in HTTPResponse.begin(self)
#     329 # read until we get a non-100 response
#     330 while True:
# --> 331     version, status, reason = self._read_status()
#     332     if status != CONTINUE:
#     333         break
#
# File ~\anaconda3\Lib\http\client.py:292, in HTTPResponse._read_status(self)
#     291 def _read_status(self):
# --> 292     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     293     if len(line) > _MAXLINE:
#     294         raise LineTooLong("status line")
#
# File ~\anaconda3\Lib\socket.py:719, in SocketIO.readinto(self, b)
#     717     raise OSError("cannot read from timed out object")
#     718 try:
# --> 719     return self._sock.recv_into(b)
#     720 except timeout:
#     721     self._timeout_occurred = True
#
# File ~\anaconda3\Lib\ssl.py:1304, in SSLSocket.recv_into(self, buffer, nbytes, flags)
#    1300     if flags != 0:
#    1301         raise ValueError(
#    1302           "non-zero flags not allowed in calls to recv_into() on %s" %
#    1303           self.__class__)
# -> 1304     return self.read(nbytes, buffer)
#    1305 else:
#    1306     return super().recv_into(buffer, nbytes, flags)
#
# File ~\anaconda3\Lib\ssl.py:1138, in SSLSocket.read(self, len, buffer)
#    1136 try:
#    1137     if buffer is not None:
# -> 1138         return self._sslobj.read(len, buffer)
#    1139     else:
#    1140         return self._sslobj.read(len)
#
# KeyboardInterrupt:

# %%
df = pd.DataFrame(books)

print("Total Movies:", len(df))
print(df.head())
# Out:
# Total Movies: 0
# Empty DataFrame
# Columns: []
# Index: []

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5020 entries, 0 to 5019
# Data columns (total 4 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   title        5020 non-null   object
#  1   description  5020 non-null   object
#  2   authors      5020 non-null   object
#  3   categories   5020 non-null   object
# dtypes: object(4)
# memory usage: 157.0+ KB

# %%
df.isnull().sum()
# Out:
# title          0
# description    0
# authors        0
# categories     0
# dtype: int64

# %%
df.to_csv("books_data.csv", index=False)

print("Dataset Saved Successfully")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 df.to_csv("books_data.csv", index=False)
#       3 print("Dataset Saved Successfully")
#
# NameError: name 'df' is not defined

# %%
import pandas as pd

df = pd.read_csv("books_data.csv")

df.head()
# Out:
#                                           title description  \
# 0          Library of Congress Subject Headings         NaN
# 1          Library of Congress Subject Headings         NaN
# 2                            The Royal Magazine         NaN
# 3                            Pearson's Magazine         NaN
# 4  Catalogue of the Oakland Free Public Library         NaN
#
#                                              authors  \
# 0                            ['Library of Congress']
# 1  ['Library of Congress. Cataloging Policy and S...
# 2                                                 []
# 3                                                 []
# 4                           ['Oakland Free Library']
#
#                                   categories
# 0  ['Subject headings, Library of Congress']
# 1  ['Subject headings, Library of Congress']
# 2                                         []
# 3                        ['English fiction']
# 4                       ['Library catalogs']

# %%
df.isnull().sum()
# Out:
# title             0
# description    3310
# authors           0
# categories        0
# dtype: int64

# %%
df["description"] = df["description"].fillna("")
df["categories"] = df["categories"].fillna("")

# %%
df.isnull().sum()
# Out:
# title          0
# description    0
# authors        0
# categories     0
# dtype: int64

# %%
df["content"] = (
    df["description"] + " " +
    df["categories"]
)

# %%
df["content"] = df["content"].str.lower()

# %%
df.tail()
# Out:
#                                                   title  \
# 5015  Summarized Proceedings of the American Associa...
# 5016                     Engineered Materials Abstracts
# 5017                     SPIE ... Directory for Members
# 5018                            The Electrical Engineer
# 5019  Disha 15 Mock Test Series NTA JEE Main 2026 wi...
#
#                                             description  \
# 5015
# 5016
# 5017
# 5018
# 5019  The updated 5th edition of Disha’s 15 Mock Tes...
#
#                                                 authors  \
# 5015  ['American Association for the Advancement of ...
# 5016                                                 []
# 5017  ['Society of Photo-Optical Instrumentation Eng...
# 5018                                                 []
# 5019                                  ['Disha Experts']
#
#                        categories  \
# 5015                  ['Science']
# 5016        ['Ceramic materials']
# 5017                ['Engineers']
# 5018   ['Electrical engineering']
# 5019  ['Antiques & Collectibles']
#
#                                                 content
# 5015                                        ['science']
# 5016                              ['ceramic materials']
# 5017                                      ['engineers']
# 5018                         ['electrical engineering']
# 5019  the updated 5th edition of disha’s 15 mock tes...

# %%
import re
def remove_html(text):
    return re.sub(r'<.*?>','',str(text))

# %%
df['content']=df['content'].apply(remove_html)

# %%
def remove_url(text):
    return re.sub(r'https?://\S+|www\.\S+', '', text)

df["content"] = df["content"].apply(remove_url)

# %%
import string

def remove_punctuation(text):
    return text.translate(
        str.maketrans('', '', string.punctuation)
    )

df["content"] = df["content"].apply(remove_punctuation)

# %%
def remove_numbers(text):
    return re.sub(r'\d+', '', text)

df["content"] = df["content"].apply(remove_numbers)

# %%
def remove_spaces(text):
    return re.sub(r'\s+', ' ', text).strip()

df["content"] = df["content"].apply(remove_spaces)

# %%
import nltk

nltk.download('punkt')
nltk.download('punkt_tab')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\LENOVO\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package punkt_tab to
# [nltk_data]     C:\Users\LENOVO\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
# True

# %%
from nltk.tokenize import word_tokenize
df["tokens"]=df["content"].apply(word_tokenize)

# %%
from nltk.corpus import stopwords

nltk.download('stopwords')

stop_words = set(stopwords.words('english'))

df["tokens"] = df["tokens"].apply(
    lambda words: [
        word for word in words
        if word not in stop_words
    ]
)
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\LENOVO\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
# !pip install spacy
# !python -m spacy download en_core_web_sm
# Out:
# Requirement already satisfied: spacy in C:\Users\LENOVO\anaconda3\Lib\site-packages (3.8.14)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in C:\Users\LENOVO\anaconda3\Lib\site-packages (from spacy) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in C:\Users\LENOVO\anaconda3\Lib\site-packages (from spacy) (1.0.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in C:\Users\LENOVO\anaconda3\Lib\site-packages (from spacy) (1.0.15)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in C:\Users\LENOVO\anaconda3\Lib\site-packages (from spacy) (2.0.13)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in C:\Users\LENOVO\anaconda3\Lib\site-packages (from spacy) (3.0.13)
# Requirement already satisfied: thinc<8.4.0,>=8.3.12 in C:\Users\LENOVO\anaconda3\Lib\site-packages (from spacy) (8.3.13)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in C:\Users\LENOVO\anaconda3\Lib\site-packages (from spacy) (1.1.3)
# Requirement already satisfied: srsly<3.0.0,>=2.5.3 in C:\Users\LENOVO\anaconda3\Lib\site-packages (from spacy) (2.5.3)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in C:\Users\LENOVO\anaconda3\Lib\site-packages (from spacy) (2.0.10)
# Requirement already satisfied: weasel<2.0.0,>=1.0.0 in C:\Users\LENOVO\anaconda3\Lib\site-packages (from spacy) (1.0.0)
# Requirement already satisfied: confection<2.0.0,>=1.3.2 in C:\Users\LENOVO\anaconda3\Lib\site-packages (from spacy) (1.3.3)
# Requirement already satisfied: typer<1.0.0,>=0.3.0 in C:\Users\LENOVO\anaconda3\Lib\site-packages (from spacy) (0.17.4)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in C:\Users\LENOVO\AppData\Roaming\Python\Python313\site-packages (from spacy) (4.67.3)
# Requirement already satisfied: numpy>=1.19.0 in C:\Users\LENOVO\AppData\Roaming\Python\Python313\site-packages (from spacy) (2.4.5)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in C:\Users\LENOVO\AppData\Roaming\Python\Python313\site-packages (from spacy) (2.32.5)
# Requirement already satisfied: pydantic<3.0.0,>=2.0.0 in C:\Users\LENOVO\AppData\Roaming\Python\Python313\site-packages (from spacy) (2.12.5)
# Requirement already satisfied: jinja2 in C:\Users\LENOVO\AppData\Roaming\Python\Python313\site-packages (from spacy) (3.1.6)
# Requirement already satisfied: setuptools in C:\Users\LENOVO\AppData\Roaming\Python\Python313\site-packages (from spacy) (81.0.0)
# Requirement already satisfied: packaging>=20.0 in C:\Users\LENOVO\AppData\Roaming\Python\Python313\site-packages (from spacy) (25.0)
# Requirement already satisfied: annotated-types>=0.6.0 in C:\Users\LENOVO\AppData\Roaming\Python\Python313\site-packages (from pydantic<3.0.0,>=2.0.0->spacy) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.5 in C:\Users\LENOVO\AppData\Roaming\Python\Python313\site-packages (from pydantic<3.0.0,>=2.0.0->spacy) (2.41.5)
# Requirement already satisfied: typing-extensions>=4.14.1 in C:\Users\LENOVO\AppData\Roaming\Python\Python313\site-packages (from pydantic<3.0.0,>=2.0.0->spacy) (4.14.1)
# Requirement already satisfied: typing-inspection>=0.4.2 in C:\Users\LENOVO\AppData\Roaming\Python\Python313\site-packages (from pydantic<3.0.0,>=2.0.0->spacy) (0.4.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in C:\Users\LENOVO\AppData\Roaming\Python\Python313\site-packages (from requests<3.0.0,>=2.13.0->spacy) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in C:\Users\LENOVO\AppData\Roaming\Python\Python313\site-packages (from requests<3.0.0,>=2.13.0->spacy) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in C:\Users\LENOVO\AppData\Roaming\Python\Python313\site-packages (from requests<3.0.0,>=2.13.0->spacy) (2.6.3)
# Requirement already satisfied: certifi>=2017.4.17 in C:\Users\LENOVO\AppData\Roaming\Python\Python313\site-packages (from requests<3.0.0,>=2.13.0->spacy) (2026.1.4)
# Requirement already satisfied: blis<1.4.0,>=1.3.0 in C:\Users\LENOVO\anaconda3\Lib\site-packages (from thinc<8.4.0,>=8.3.12->spacy) (1.3.3)
# Requirement already satisfied: colorama in C:\Users\LENOVO\AppData\Roaming\Python\Python313\site-packages (from tqdm<5.0.0,>=4.38.0->spacy) (0.4.6)
# Requirement already satisfied: click>=8.0.0 in C:\Users\LENOVO\AppData\Roaming\Python\Python313\site-packages (from typer<1.0.0,>=0.3.0->spacy) (8.2.1)
# Requirement already satisfied: shellingham>=1.3.0 in C:\Users\LENOVO\anaconda3\Lib\site-packages (from typer<1.0.0,>=0.3.0->spacy) (1.5.4)
# Requirement already satisfied: rich>=10.11.0 in C:\Users\LENOVO\anaconda3\Lib\site-packages (from typer<1.0.0,>=0.3.0->spacy) (14.2.0)
# Requirement already satisfied: cloudpathlib>=0.7.0 in C:\Users\LENOVO\anaconda3\Lib\site-packages (from weasel<2.0.0,>=1.0.0->spacy) (0.24.0)
# Requirement already satisfied: smart-open>=5.2.1 in C:\Users\LENOVO\anaconda3\Lib\site-packages (from weasel<2.0.0,>=1.0.0->spacy) (7.6.1)
# Requirement already satisfied: httpx>=0.24.0 in C:\Users\LENOVO\AppData\Roaming\Python\Python313\site-packages (from weasel<2.0.0,>=1.0.0->spacy) (0.28.1)
# Requirement already satisfied: anyio in C:\Users\LENOVO\AppData\Roaming\Python\Python313\site-packages (from httpx>=0.24.0->weasel<2.0.0,>=1.0.0->spacy) (4.12.1)
# Requirement already satisfied: httpcore==1.* in C:\Users\LENOVO\AppData\Roaming\Python\Python313\site-packages (from httpx>=0.24.0->weasel<2.0.0,>=1.0.0->spacy) (1.0.9)
# Requirement already satisfied: h11>=0.16 in C:\Users\LENOVO\AppData\Roaming\Python\Python313\site-packages (from httpcore==1.*->httpx>=0.24.0->weasel<2.0.0,>=1.0.0->spacy) (0.16.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in C:\Users\LENOVO\AppData\Roaming\Python\Python313\site-packages (from rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy) (4.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in C:\Users\LENOVO\AppData\Roaming\Python\Python313\site-packages (from rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy) (2.19.2)
# Requirement already satisfied: mdurl~=0.1 in C:\Users\LENOVO\AppData\Roaming\Python\Python313\site-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy) (0.1.2)
# Requirement already satisfied: wrapt in C:\Users\LENOVO\anaconda3\Lib\site-packages (from smart-open>=5.2.1->weasel<2.0.0,>=1.0.0->spacy) (1.17.0)
# Requirement already satisfied: MarkupSafe>=2.0 in C:\Users\LENOVO\AppData\Roaming\Python\Python313\site-packages (from jinja2->spacy) (3.0.2)
# Collecting en-core-web-sm==3.8.0
#   Downloading en_core_web_sm-3.8.0-py3-none-any.whl (12.8 MB)
#      ---------------------------------------- 0.0/12.8 MB ? eta -:--:--
#      ---------------------------------------- 0.0/12.8 MB ? eta -:--:--
#       --------------------------------------- 0.3/12.8 MB ? eta -:--:--
#      --- ------------------------------------ 1.0/12.8 MB 2.0 MB/s eta 0:00:06
#      ---- ----------------------------------- 1.6/12.8 MB 2.2 MB/s eta 0:00:06
#      ----- ---------------------------------- 1.8/12.8 MB 2.0 MB/s eta 0:00:06
#      -------- ------------------------------- 2.6/12.8 MB 2.4 MB/s eta 0:00:05
#      --------- ------------------------------ 3.1/12.8 MB 2.4 MB/s eta 0:00:05
#      ----------- ---------------------------- 3.7/12.8 MB 2.4 MB/s eta 0:00:04
#      ------------- -------------------------- 4.2/12.8 MB 2.5 MB/s eta 0:00:04
#      ------------- -------------------------- 4.5/12.8 MB 2.4 MB/s eta 0:00:04
#      ------------- -------------------------- 4.5/12.8 MB 2.4 MB/s eta 0:00:04
#      ------------- -------------------------- 4.5/12.8 MB 2.4 MB/s eta 0:00:04
#      -------------- ------------------------- 4.7/12.8 MB 1.8 MB/s eta 0:00:05
#      -------------- ------------------------- 4.7/12.8 MB 1.8 MB/s eta 0:00:05
#      ---------------- ----------------------- 5.2/12.8 MB 1.7 MB/s eta 0:00:05
#      ----------------- ---------------------- 5.5/12.8 MB 1.7 MB/s eta 0:00:05
#      ------------------ --------------------- 6.0/12.8 MB 1.7 MB/s eta 0:00:04
#      ------------------- -------------------- 6.3/12.8 MB 1.7 MB/s eta 0:00:04
#      --------------------- ------------------ 6.8/12.8 MB 1.7 MB/s eta 0:00:04
#      ---------------------- ----------------- 7.3/12.8 MB 1.8 MB/s eta 0:00:04
#      ----------------------- ---------------- 7.6/12.8 MB 1.8 MB/s eta 0:00:03
#      ------------------------- -------------- 8.1/12.8 MB 1.8 MB/s eta 0:00:03
#      --------------------------- ------------ 8.7/12.8 MB 1.8 MB/s eta 0:00:03
#      ---------------------------- ----------- 9.2/12.8 MB 1.9 MB/s eta 0:00:02
#      ------------------------------- -------- 10.0/12.8 MB 1.9 MB/s eta 0:00:02
#      --------------------------------- ------ 10.7/12.8 MB 2.0 MB/s eta 0:00:02
#      ----------------------------------- ---- 11.3/12.8 MB 2.0 MB/s eta 0:00:01
#      ------------------------------------ --- 11.5/12.8 MB 2.0 MB/s eta 0:00:01
#      ------------------------------------- -- 12.1/12.8 MB 2.0 MB/s eta 0:00:01
#      ---------------------------------------  12.6/12.8 MB 2.0 MB/s eta 0:00:01
#      ---------------------------------------- 12.8/12.8 MB 2.0 MB/s  0:00:06
# [+] Download and installation successful
# You can now load the package via spacy.load('en_core_web_sm')

# %%
import spacy

nlp = spacy.load("en_core_web_sm")

def lemmatize(tokens):

    doc = nlp(" ".join(tokens))

    return [
        token.lemma_
        for token in doc
    ]

df["tokens"] = df["tokens"].apply(lemmatize)

# %%
df["processed_text"] = df["tokens"].apply(
    lambda x: " ".join(x)
)

# %%
df.head()
# Out:
#                                           title description  \
# 0          Library of Congress Subject Headings
# 1          Library of Congress Subject Headings
# 2                            The Royal Magazine
# 3                            Pearson's Magazine
# 4  Catalogue of the Oakland Free Public Library
#
#                                              authors  \
# 0                            ['Library of Congress']
# 1  ['Library of Congress. Cataloging Policy and S...
# 2                                                 []
# 3                                                 []
# 4                           ['Oakland Free Library']
#
#                                   categories  \
# 0  ['Subject headings, Library of Congress']
# 1  ['Subject headings, Library of Congress']
# 2                                         []
# 3                        ['English fiction']
# 4                       ['Library catalogs']
#
#                                 content  \
# 0  subject headings library of congress
# 1  subject headings library of congress
# 2
# 3                       english fiction
# 4                      library catalogs
#
#                                   tokens                    processed_text
# 0  [subject, heading, library, congress]  subject heading library congress
# 1  [subject, heading, library, congress]  subject heading library congress
# 2                                     []
# 3                     [english, fiction]                   english fiction
# 4                     [library, catalog]                   library catalog

# %%
# !pip install gensim
# Out:
# Collecting gensim
#   Downloading gensim-4.4.0-cp313-cp313-win_amd64.whl.metadata (8.6 kB)
# Requirement already satisfied: numpy>=1.18.5 in C:\Users\LENOVO\AppData\Roaming\Python\Python313\site-packages (from gensim) (2.4.5)
# Requirement already satisfied: scipy>=1.7.0 in C:\Users\LENOVO\AppData\Roaming\Python\Python313\site-packages (from gensim) (1.17.1)
# Requirement already satisfied: smart_open>=1.8.1 in C:\Users\LENOVO\anaconda3\Lib\site-packages (from gensim) (7.6.1)
# Requirement already satisfied: wrapt in C:\Users\LENOVO\anaconda3\Lib\site-packages (from smart_open>=1.8.1->gensim) (1.17.0)
# Downloading gensim-4.4.0-cp313-cp313-win_amd64.whl (24.4 MB)
#    ---------------------------------------- 0.0/24.4 MB ? eta -:--:--
#    ---------------------------------------- 0.0/24.4 MB ? eta -:--:--
#    ---------------------------------------- 0.0/24.4 MB ? eta -:--:--
#    ---------------------------------------- 0.3/24.4 MB ? eta -:--:--
#     --------------------------------------- 0.5/24.4 MB 810.4 kB/s eta 0:00:30
#     --------------------------------------- 0.5/24.4 MB 810.4 kB/s eta 0:00:30
#    - -------------------------------------- 0.8/24.4 MB 664.5 kB/s eta 0:00:36
#    - -------------------------------------- 0.8/24.4 MB 664.5 kB/s eta 0:00:36
#    - -------------------------------------- 1.0/24.4 MB 730.9 kB/s eta 0:00:32
#    -- ------------------------------------- 1.3/24.4 MB 758.8 kB/s eta 0:00:31
#    -- ------------------------------------- 1.3/24.4 MB 758.8 kB/s eta 0:00:31
#    -- ------------------------------------- 1.6/24.4 MB 721.9 kB/s eta 0:00:32
#    --- ------------------------------------ 1.8/24.4 MB 782.7 kB/s eta 0:00:29
#    --- ------------------------------------ 2.1/24.4 MB 839.3 kB/s eta 0:00:27
#    --- ------------------------------------ 2.4/24.4 MB 891.0 kB/s eta 0:00:25
#    ---- ----------------------------------- 2.9/24.4 MB 977.9 kB/s eta 0:00:22
#    ---- ----------------------------------- 2.9/24.4 MB 977.9 kB/s eta 0:00:22
#    ----- ---------------------------------- 3.1/24.4 MB 951.7 kB/s eta 0:00:23
#    ------ --------------------------------- 3.7/24.4 MB 1.0 MB/s eta 0:00:20
#    ------ --------------------------------- 3.9/24.4 MB 1.1 MB/s eta 0:00:20
#    ------ --------------------------------- 4.2/24.4 MB 1.1 MB/s eta 0:00:19
#    ----------------------------- ---------- 18.1/24.4 MB 883.9 kB/s eta 0:00:08
#    ------------------------------ --------- 18.4/24.4 MB 887.0 kB/s eta 0:00:07
#    ------------------------------ --------- 18.4/24.4 MB 887.0 kB/s eta 0:00:07
#    ------------------------------ --------- 18.6/24.4 MB 883.6 kB/s eta 0:00:07
#    ------------------------------ --------- 18.6/24.4 MB 883.6 kB/s eta 0:00:07
#    ------------------------------ --------- 18.9/24.4 MB 878.5 kB/s eta 0:00:07
#    ------------------------------- -------- 19.1/24.4 MB 882.3 kB/s eta 0:00:06
#    ------------------------------- -------- 19.4/24.4 MB 881.5 kB/s eta 0:00:06
#    ------------------------------- -------- 19.4/24.4 MB 881.5 kB/s eta 0:00:06
#    -------------------------------- ------- 19.7/24.4 MB 884.0 kB/s eta 0:00:06
#    --------------------------------- ------ 20.2/24.4 MB 892.5 kB/s eta 0:00:05
#    --------------------------------- ------ 20.2/24.4 MB 892.5 kB/s eta 0:00:05
#    --------------------------------- ------ 20.4/24.4 MB 890.6 kB/s eta 0:00:05
#    --------------------------------- ------ 20.4/24.4 MB 890.6 kB/s eta 0:00:05
#    --------------------------------- ------ 20.7/24.4 MB 886.4 kB/s eta 0:00:05
#    ---------------------------------- ----- 21.0/24.4 MB 885.9 kB/s eta 0:00:04
#    ---------------------------------- ----- 21.2/24.4 MB 888.4 kB/s eta 0:00:04
#    ---------------------------------- ----- 21.2/24.4 MB 888.4 kB/s eta 0:00:04
#    ----------------------------------- ---- 21.5/24.4 MB 888.1 kB/s eta 0:00:04
#    ----------------------------------- ---- 21.8/24.4 MB 888.2 kB/s eta 0:00:03
#    ------------------------------------ --- 22.0/24.4 MB 893.9 kB/s eta 0:00:03
#    ------------------------------------ --- 22.3/24.4 MB 892.6 kB/s eta 0:00:03
#    ------------------------------------ --- 22.5/24.4 MB 897.4 kB/s eta 0:00:03
#    ------------------------------------ --- 22.5/24.4 MB 897.4 kB/s eta 0:00:03
#    ------------------------------------- -- 22.8/24.4 MB 893.3 kB/s eta 0:00:02
#    ------------------------------------- -- 23.1/24.4 MB 895.8 kB/s eta 0:00:02
#    -------------------------------------- - 23.3/24.4 MB 900.1 kB/s eta 0:00:02
#    ---------------------------------------  23.9/24.4 MB 907.0 kB/s eta 0:00:01
#    ---------------------------------------  24.1/24.4 MB 910.9 kB/s eta 0:00:01
#    ---------------------------------------- 24.4/24.4 MB 913.6 kB/s  0:00:26
# Installing collected packages: gensim
# Successfully installed gensim-4.4.0

# %%
from gensim.models import Word2Vec

sentences = [text.split() for text in df["processed_text"]]

w2v_model = Word2Vec(
    sentences,
    vector_size=100,
    window=5,
    min_count=2,
    workers=4
)

# %%
import numpy as np

def get_document_vector(text):

    words = text.split()

    vectors = []

    for word in words:
        if word in w2v_model.wv:
            vectors.append(w2v_model.wv[word])

    if len(vectors) == 0:
        return np.zeros(100)

    return np.mean(vectors, axis=0)

# %%
book_vectors = np.array([
    get_document_vector(text)
    for text in df["processed_text"]
])

print(book_vectors.shape)
# Out:
# (5020, 100)

# %%
tfidf_matrix.shape
# Out:
# (5020, 14173)

# %%
w2v_model.save("word2vec.model")
